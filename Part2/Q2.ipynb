# %%
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pandas as pd

# %%
train_data = pd.read_csv("../train.csv")

# %%
train_data.dropna(subset=['gt_25k_p6', 'md_earn_wne_p10'])
# Out:
#                                                  INSTNM              CITY  \
# 0                   Kent State University at Tuscarawas  New Philadelphia
# 1                                      McDaniel College       Westminster
# 2                                York Technical College         Rock Hill
# 3                Career Training Academy-New Kensington    New Kensington
# 5                          Fort Scott Community College        Fort Scott
# 6                   University of Wisconsin-River Falls       River Falls
# 7                      Illinois Center for Broadcasting           Lombard
# 8               University of Phoenix-Pittsburgh Campus        Pittsburgh
# 11                         John Tyler Community College           Chester
# 13                       Helene Fuld College of Nursing          New York
# 14         All-State Career School-Allied Health Campus         Essington
# 15                                   Harding University            Searcy
# 16                       Western Oklahoma State College             Altus
# 17                                          Cox College       Springfield
# 19                                        Plaza College   Jackson Heights
# 20                   Strayer University-Florence Campus          Florence
# 21                            Lake-Sumter State College          Leesburg
# 22                       Capital Area Technical College       Baton Rouge
# 23                                Connors State College            Warner
# 24                          Merrillville Beauty College      Merrillville
# 25                  National University College-Arecibo           Arecibo
# 27                       Motlow State Community College         Tullahoma
# 28                            Strayer University-Irving            Irving
# 29                       McNally Smith College of Music        Saint Paul
# 31                                 Heald College-Fresno            Fresno
# 32                                         Erie 1 BOCES       West Seneca
# 33                                Lindenwood University     Saint Charles
# 36      Illinois School of Health Careers-O'Hare Campus           Chicago
# 37    International Academy of Design and Technology...       San Antonio
# 38                                      Roanoke College             Salem
# ...                                                 ...               ...
# 6202                        SUNY College at Plattsburgh       Plattsburgh
# 6203                   Regency Beauty Institute-Roanoke           Roanoke
# 6204                      Spencerian College-Louisville        Louisville
# 6205                                Cedar Crest College         Allentown
# 6206                                      Westside Tech     Winter Garden
# 6207               Southwest Minnesota State University          Marshall
# 6208                             Green Mountain College          Poultney
# 6209     Inter American University of Puerto Rico-Ponce         Mercedita
# 6210                            Milan Institute-Visalia           Visalia
# 6212              University of Phoenix-Columbia Campus          Columbia
# 6213        Minnesota State College-Southeast Technical            Winona
# 6215                     Empire Beauty School-Manitowoc         Manitowoc
# 6217           Northwestern College-Southwestern Campus        Bridgeview
# 6218      National American University-Colorado Springs  Colorado Springs
# 6220                               Capri Beauty College           Chicago
# 6221                    United Tribes Technical College          Bismarck
# 6222                                  Bastyr University           Kenmore
# 6223                 San Joaquin Valley College-Visalia           Visalia
# 6224           Florida National University-South Campus             Miami
# 6225                          Inner State Beauty School         Lyndhurst
# 6229                            Meharry Medical College         Nashville
# 6230            Texas State Technical College-Harlingen         Harlingen
# 6232               Golden Gate University-San Francisco     San Francisco
# 6233               Northwest Technology Center-Fairview          Fairview
# 6235                    Calumet College of Saint Joseph           Whiting
# 6236                  Community College of Rhode Island           Warwick
# 6237                                Pennco Tech-Bristol           Bristol
# 6239                              Daytona State College     Daytona Beach
# 6240                   The Art Institute of San Antonio       San Antonio
# 6241                                  MacCormac College           Chicago
#
#      STABBR  PREDDEG  CONTROL  LOCALE  SATVRMID  SATMTMID  SATWRMID  ACTCMMID  \
# 0        OH        2        1    32.0       NaN       NaN       NaN       NaN
# 1        MD        3        2    23.0     550.0     555.0       NaN      24.0
# 2        SC        2        1    13.0       NaN       NaN       NaN       NaN
# 3        PA        1        3    21.0       NaN       NaN       NaN       NaN
# 5        KS        1        1    33.0       NaN       NaN       NaN       NaN
# 6        WI        3        1    32.0       NaN       NaN       NaN      22.0
# 7        IL        1        3    21.0       NaN       NaN       NaN       NaN
# 8        PA        3        3    21.0       NaN       NaN       NaN       NaN
# 11       VA        2        1    21.0       NaN       NaN       NaN       NaN
# 13       NY        2        2    11.0       NaN       NaN       NaN       NaN
# 14       PA        1        3    21.0       NaN       NaN       NaN       NaN
# 15       AR        3        2    32.0     560.0     560.0       NaN      25.0
# 16       OK        2        1    41.0       NaN       NaN       NaN       NaN
# 17       MO        2        2    12.0     530.0     560.0     470.0      18.0
# 19       NY        2        3    11.0       NaN       NaN       NaN       NaN
# 20       KY        0        3     NaN       NaN       NaN       NaN       NaN
# 21       FL        2        1    22.0       NaN       NaN       NaN       NaN
# 22       LA        1        1    12.0       NaN       NaN       NaN       NaN
# 23       OK        2        1    43.0       NaN       NaN       NaN       NaN
# 24       IN        1        3    21.0       NaN       NaN       NaN       NaN
# 25       PR        2        3    13.0       NaN       NaN       NaN       NaN
# 27       TN        2        1    41.0     445.0     453.0       NaN      19.0
# 28       TX        0        3     NaN       NaN       NaN       NaN       NaN
# 29       MN        3        3    11.0       NaN       NaN       NaN       NaN
# 31       CA        2        3    11.0       NaN       NaN       NaN       NaN
# 32       NY        1        1    21.0       NaN       NaN       NaN       NaN
# 33       MO        3        2    13.0     490.0     525.0     465.0      23.0
# 36       IL        1        3    11.0       NaN       NaN       NaN       NaN
# 37       TX        3        3    11.0       NaN       NaN       NaN       NaN
# 38       VA        3        2    22.0     545.0     540.0     535.0      24.0
# ...     ...      ...      ...     ...       ...       ...       ...       ...
# 6202     NY        3        1    32.0     505.0     520.0       NaN      22.0
# 6203     VA        1        3    13.0       NaN       NaN       NaN       NaN
# 6204     KY        1        3    21.0       NaN       NaN       NaN       NaN
# 6205     PA        3        2    12.0     475.0     470.0     460.0      21.0
# 6206     FL        1        1    21.0       NaN       NaN       NaN       NaN
# 6207     MN        3        1    33.0       NaN       NaN       NaN      22.0
# 6208     VT        3        2    42.0       NaN       NaN       NaN       NaN
# 6209     PR        3        2    22.0       NaN       NaN       NaN       NaN
# 6210     CA        1        3    12.0       NaN       NaN       NaN       NaN
# 6212     SC        3        3    21.0       NaN       NaN       NaN       NaN
# 6213     MN        1        1    32.0       NaN       NaN       NaN       NaN
# 6215     WI        1        3    32.0       NaN       NaN       NaN       NaN
# 6217     IL        2        3    21.0       NaN       NaN       NaN       NaN
# 6218     CO        3        3    11.0       NaN       NaN       NaN       NaN
# 6220     IL        1        3    11.0       NaN       NaN       NaN       NaN
# 6221     ND        1        2    23.0       NaN       NaN       NaN       NaN
# 6222     WA        3        2    21.0       NaN       NaN       NaN       NaN
# 6223     CA        2        3    41.0       NaN       NaN       NaN       NaN
# 6224     FL        0        3     NaN       NaN       NaN       NaN       NaN
# 6225     OH        1        3    21.0       NaN       NaN       NaN       NaN
# 6229     TN        4        2    11.0       NaN       NaN       NaN       NaN
# 6230     TX        2        1    13.0       NaN       NaN       NaN       NaN
# 6232     CA        3        2    11.0       NaN       NaN       NaN       NaN
# 6233     OK        1        1    43.0       NaN       NaN       NaN       NaN
# 6235     IN        3        2    21.0     425.0     435.0     391.0      18.0
# 6236     RI        2        1    13.0       NaN       NaN       NaN       NaN
# 6237     PA        1        3    21.0       NaN       NaN       NaN       NaN
# 6239     FL        2        1    13.0       NaN       NaN       NaN       NaN
# 6240     TX        2        3    11.0       NaN       NaN       NaN       NaN
# 6241     IL        2        2    11.0       NaN       NaN       NaN       NaN
#
#           ...       PCTFLOAN  UG25abv  GRAD_DEBT_MDN_SUPP  \
# 0         ...         0.6196   0.3453             26225.0
# 1         ...         0.6629   0.0313             27000.0
# 2         ...         0.2122   0.4024             10475.0
# 3         ...         0.6386   0.4540              9500.0
# 5         ...         0.4036   0.2206                 NaN
# 6         ...         0.6503   0.1126             24700.0
# 7         ...         0.8797   0.5118              9500.0
# 8         ...         0.6814   0.9189             35500.0
# 11        ...         0.1407   0.2917             11699.0
# 13        ...         0.5815   0.9621             13750.0
# 14        ...         0.9630   0.3771              6333.0
# 15        ...         0.5573   0.0580             26250.0
# 16        ...         0.0677   0.3266              9000.0
# 17        ...         0.7912   0.6466             22082.0
# 19        ...         0.8003   0.5551             14278.5
# 20        ...            NaN      NaN             39499.5
# 21        ...         0.0517   0.2633              6375.0
# 22        ...         0.0000   0.4815                 NaN
# 23        ...         0.3821   0.3801             11250.0
# 24        ...         0.0000   0.5161                 NaN
# 25        ...         0.5347   0.3709              7533.0
# 27        ...         0.1207   0.2439              5025.0
# 28        ...            NaN      NaN             39499.5
# 29        ...         0.7034   0.1597             25750.0
# 31        ...         0.8150   0.4350             11250.0
# 32        ...         0.9534   0.5484              9500.0
# 33        ...         0.6477   0.2752             27000.0
# 36        ...         0.7427   0.4457              9182.0
# 37        ...         0.9513   0.5871             29375.0
# 38        ...         0.7034   0.0330             27000.0
# ...       ...            ...      ...                 ...
# 6202      ...         0.6593   0.1153             22475.5
# 6203      ...         0.8699   0.3448             14144.0
# 6204      ...         0.6072   0.5722             18922.0
# 6205      ...         0.8337   0.4510             30575.0
# 6206      ...         0.0000   0.4808                 NaN
# 6207      ...         0.2639   0.0759             24200.0
# 6208      ...         0.7111   0.0407             25000.0
# 6209      ...         0.2217   0.2720              8500.0
# 6210      ...         0.6462   0.3672              9500.0
# 6212      ...         0.6520   0.8315             35500.0
# 6213      ...         0.6154   0.4264             13500.0
# 6215      ...         0.7000   0.3611              9522.0
# 6217      ...         0.9475   0.5833             30500.0
# 6218      ...         0.6218   0.8541             34486.0
# 6220      ...         0.4677   0.4375             12500.0
# 6221      ...         0.3738   0.5168             12697.0
# 6222      ...         0.6637   0.6062             22770.0
# 6223      ...         0.9593   0.5495             19648.5
# 6224      ...            NaN      NaN             25766.0
# 6225      ...         0.0000   0.4532                 NaN
# 6229      ...            NaN      NaN                 NaN
# 6230      ...         0.1216   0.2776              6562.5
# 6232      ...         0.5912   0.8779             28117.5
# 6233      ...         0.0000   0.0515                 NaN
# 6235      ...         0.5559   0.4727             24223.5
# 6236      ...         0.2801   0.3778              8500.0
# 6237      ...         0.6987   0.4574              9500.0
# 6239      ...         0.3586   0.4128              9323.0
# 6240      ...         0.7332   0.3704             30500.0
# 6241      ...         0.8144   0.6419             25034.5
#
#       GRAD_DEBT_MDN10YR_SUPP  RPY_3YR_RT_SUPP  C150_4_POOLED_SUPP  \
# 0                 291.151261         0.690392            0.191335
# 1                 299.755350         0.949511            0.725667
# 2                 116.293974         0.569444                 NaN
# 3                 105.469475         0.672297                 NaN
# 5                        NaN         0.506419                 NaN
# 6                 274.220635         0.915487            0.527869
# 7                 105.469475         0.676955                 NaN
# 8                 394.122775         0.406534            0.101329
# 11                129.882883         0.618397                 NaN
# 13                152.653188         0.777409            0.617650
# 14                 70.309283         0.367068                 NaN
# 15                291.428812         0.876754            0.614735
# 16                 99.918450         0.580709                 NaN
# 17                245.155468         0.787402            0.678141
# 19                158.520621         0.644843            0.706223
# 20                438.525424         0.444775                 NaN
# 21                 70.775569         0.655518            0.346807
# 22                       NaN              NaN                 NaN
# 23                124.898062         0.528129                 NaN
# 24                       NaN         0.148148                 NaN
# 25                 83.631743         0.506379            0.186242
# 27                 55.787801         0.605583                 NaN
# 28                438.525424         0.444775                 NaN
# 29                285.877788         0.748184            0.440553
# 31                124.898062         0.462308                 NaN
# 32                105.469475         0.698842                 NaN
# 33                299.755350         0.794253            0.427840
# 36                101.939023         0.401961                 NaN
# 37                326.122719         0.388268            0.200000
# 38                299.755350         0.891688            0.647963
# ...                      ...              ...                 ...
# 6202              249.524125         0.864393            0.604257
# 6203              157.027395         0.474970                 NaN
# 6204              210.072990         0.470103                 NaN
# 6205              339.445179         0.829431            0.605023
# 6206                     NaN              NaN                 NaN
# 6207              268.669610         0.839775            0.419759
# 6208              277.551250         0.797235            0.414047
# 6209               94.367425         0.480897            0.309972
# 6210              105.469475         0.374396                 NaN
# 6212              394.122775         0.406534            0.112802
# 6213              149.877675         0.671810                 NaN
# 6215              105.713720         0.473684                 NaN
# 6217              338.612525         0.418148                 NaN
# 6218              382.865296         0.483530            0.142840
# 6220              138.775625         0.215190                 NaN
# 6221              140.962729         0.090909            0.160875
# 6222              252.793679         0.872093                 NaN
# 6223              218.138629         0.426538                 NaN
# 6224              286.055420         0.508388                 NaN
# 6225                     NaN              NaN                 NaN
# 6229                     NaN              NaN                 NaN
# 6230               72.857203         0.444821                 NaN
# 6232              312.161891         0.831169                 NaN
# 6233                     NaN              NaN                 NaN
# 6235              268.930508         0.614754            0.317063
# 6236               94.367425         0.744503                 NaN
# 6237              105.469475         0.505597                 NaN
# 6239              103.504412         0.484982            0.328524
# 6240              338.612525         0.544359                 NaN
# 6241              277.934271         0.633987                 NaN
#
#       C200_L4_POOLED_SUPP  md_earn_wne_p10  gt_25k_p6  gt_25k_05_p6
# 0                     NaN          36600.0   0.589350           1.0
# 1                     NaN          44600.0   0.725173           1.0
# 2                0.183209          25300.0   0.421260           0.0
# 3                0.786278          23400.0   0.297398           0.0
# 5                0.430146          26900.0   0.471015           0.0
# 6                     NaN          39700.0   0.674946           1.0
# 7                0.832131          29400.0   0.520619           1.0
# 8                     NaN          53400.0   0.705231           1.0
# 11               0.154572          33800.0   0.544224           1.0
# 13                    NaN          82100.0   0.934211           1.0
# 14               0.493700          36800.0   0.566919           1.0
# 15                    NaN          38600.0   0.630909           1.0
# 16               0.266596          31100.0   0.500824           1.0
# 17                    NaN          43800.0   0.715210           1.0
# 19                    NaN          23400.0   0.320497           0.0
# 20                    NaN          51700.0   0.722577           1.0
# 21                    NaN          30400.0   0.462025           0.0
# 22               0.489418          27000.0   0.419159           0.0
# 23               0.223395          29800.0   0.468137           0.0
# 24               0.470564          14200.0   0.318182           0.0
# 25                    NaN          16700.0   0.195995           0.0
# 27               0.213312          26700.0   0.438066           0.0
# 28                    NaN          51700.0   0.722577           1.0
# 29                    NaN          30300.0   0.452012           0.0
# 31               0.413154          30100.0   0.407911           0.0
# 32               0.953642          34800.0   0.582011           1.0
# 33                    NaN          39700.0   0.673625           1.0
# 36               0.603861          19300.0   0.294710           0.0
# 37                    NaN          27800.0   0.466302           0.0
# 38                    NaN          42500.0   0.689949           1.0
# ...                   ...              ...        ...           ...
# 6202                  NaN          40600.0   0.617538           1.0
# 6203                  NaN          19600.0   0.333333           0.0
# 6204             0.502094          30900.0   0.475886           0.0
# 6205                  NaN          45200.0   0.707747           1.0
# 6206             0.595758          22300.0   0.388889           0.0
# 6207                  NaN          35600.0   0.616564           1.0
# 6208                  NaN          30600.0   0.381107           0.0
# 6209                  NaN          20000.0   0.230852           0.0
# 6210             0.729192          23400.0   0.394391           0.0
# 6212                  NaN          53400.0   0.705231           1.0
# 6213             0.355263          32800.0   0.601286           1.0
# 6215             0.496333          16700.0   0.183857           0.0
# 6217             0.541048          29700.0   0.463607           0.0
# 6218                  NaN          37800.0   0.573896           1.0
# 6220             0.367378          15500.0   0.247619           0.0
# 6221                  NaN          15700.0   0.238235           0.0
# 6222                  NaN          32000.0   0.593750           1.0
# 6223             0.564519          26900.0   0.471349           0.0
# 6224                  NaN          22000.0   0.381846           0.0
# 6225             0.745715          16800.0   0.147059           0.0
# 6229                  NaN         126700.0   0.925714           1.0
# 6230             0.274777          26900.0   0.430858           0.0
# 6232                  NaN          64200.0   0.850622           1.0
# 6233             0.937500          18400.0   0.301887           0.0
# 6235                  NaN          37200.0   0.667568           1.0
# 6236             0.159753          29100.0   0.461339           0.0
# 6237             0.819554          33800.0   0.565008           1.0
# 6239                  NaN          27000.0   0.444702           0.0
# 6240                  NaN          32900.0   0.514155           1.0
# 6241             0.134590          28400.0   0.496000           0.0
#
# [4468 rows x 43 columns]

# %%
train_data.columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'PREDDEG', 'CONTROL', 'LOCALE', 'SATVRMID',
#        'SATMTMID', 'SATWRMID', 'ACTCMMID', 'ACTENMID', 'ACTMTMID', 'ACTWRMID',
#        'SAT_AVG', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE', 'UGDS_BLACK',
#        'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI', 'UGDS_2MOR',
#        'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'NPT4_PUB', 'NPT4_PRIV', 'PCTPELL',
#        'RET_FT4', 'RET_FTL4', 'RET_PT4', 'RET_PTL4', 'PCTFLOAN', 'UG25abv',
#        'GRAD_DEBT_MDN_SUPP', 'GRAD_DEBT_MDN10YR_SUPP', 'RPY_3YR_RT_SUPP',
#        'C150_4_POOLED_SUPP', 'C200_L4_POOLED_SUPP', 'md_earn_wne_p10',
#        'gt_25k_p6', 'gt_25k_05_p6'],
#       dtype='object')

# %%
# We need to create some treatment variable columns

# Binary columns indicating if a university is public, private not for profit, or private for profit
train_data['CONTROL_PUBLIC'] = (train_data['CONTROL'] == 1)
train_data['CONTROL_PRIVATE_NP'] = (train_data['CONTROL'] == 2)
train_data['CONTROL_PRIVATE_FP'] = (train_data['CONTROL'] == 3)

# What about attending a big or small school? Denote by 1 if a university has a population
# above the average (~2300)
train_data['UGDS_AVG_THRESH'] = (train_data['UGDS'] >= train_data['UGDS'].mean())

# What about attending a really big school (>10000 undergrads)? Or a really small
# school (<1000) undergrads?
train_data['UGDS_10000_THRESH'] = (train_data['UGDS'] >= 10000)
train_data['UGDS_1000_THRESH'] = (train_data['UGDS'] < 1000)

train_data['UGDS_25abv_AVG_THRESH'] = (train_data['UG25abv'] >= train_data['UG25abv'].mean())

# %%
train_data['gt_25k_p6_BIN'] = (train_data['gt_25k_p6'] >= .5)
train_data['gt_25k_p6_BIN'] = train_data['gt_25k_p6_BIN'].astype(int)

# %%
ols_results = smf.ols('md_earn_wne_p10 ~ CONTROL_PUBLIC + CONTROL_PRIVATE_NP + CONTROL_PRIVATE_FP + UGDS_AVG_THRESH + UGDS_10000_THRESH + UGDS_1000_THRESH + UGDS_25abv_AVG_THRESH', data=train_data).fit()

# %%
ols_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.201
# Method:                 Least Squares   F-statistic:                     190.4
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):          7.59e-217
# Time:                        20:39:45   Log-Likelihood:                -48954.
# No. Observations:                4515   AIC:                         9.792e+04
# Df Residuals:                    4508   BIC:                         9.797e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                      2.767e+04    308.449     89.695      0.000    2.71e+04    2.83e+04
# CONTROL_PUBLIC[T.True]         6078.5205    339.924     17.882      0.000    5412.103    6744.938
# CONTROL_PRIVATE_NP[T.True]     1.572e+04    300.153     52.385      0.000    1.51e+04    1.63e+04
# CONTROL_PRIVATE_FP[T.True]     5864.2357    344.089     17.043      0.000    5189.653    6538.818
# UGDS_AVG_THRESH[T.True]         650.3000    609.983      1.066      0.286    -545.565    1846.165
# UGDS_10000_THRESH[T.True]      4053.5627    803.859      5.043      0.000    2477.604    5629.521
# UGDS_1000_THRESH[T.True]      -7755.9927    535.247    -14.490      0.000   -8805.340   -6706.645
# UGDS_25abv_AVG_THRESH[T.True]  1536.6095    428.033      3.590      0.000     697.454    2375.765
# ==============================================================================
# Omnibus:                     3924.811   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           296841.806
# Skew:                           3.758   Prob(JB):                         0.00
# Kurtosis:                      42.005   Cond. No.                     1.26e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 5.58e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
log_results = smf.logit('gt_25k_p6_BIN ~ CONTROL_PUBLIC + CONTROL_PRIVATE_NP + CONTROL_PRIVATE_FP + UGDS_AVG_THRESH + UGDS_10000_THRESH + UGDS_1000_THRESH + UGDS_25abv_AVG_THRESH', data=train_data).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.587164
#          Iterations 5

# %%
log_results.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/statsmodels/base/model.py:1092: RuntimeWarning: invalid value encountered in sqrt
#   bse_ = np.sqrt(np.diag(self.cov_params()))
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:877: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:1831: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          gt_25k_p6_BIN   No. Observations:                 6243
# Model:                          Logit   Df Residuals:                     6236
# Method:                           MLE   Df Model:                            6
# Date:                Wed, 13 Mar 2019   Pseudo R-squ.:                  0.1246
# Time:                        20:39:45   Log-Likelihood:                -3665.7
# converged:                       True   LL-Null:                       -4187.4
#                                         LLR p-value:                3.715e-222
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -0.0608        nan        nan        nan         nan         nan
# CONTROL_PUBLIC[T.True]           -0.1133        nan        nan        nan         nan         nan
# CONTROL_PRIVATE_NP[T.True]        0.5853        nan        nan        nan         nan         nan
# CONTROL_PRIVATE_FP[T.True]       -0.5328        nan        nan        nan         nan         nan
# UGDS_AVG_THRESH[T.True]           0.5299      0.097      5.469      0.000       0.340       0.720
# UGDS_10000_THRESH[T.True]         0.5992      0.143      4.203      0.000       0.320       0.879
# UGDS_1000_THRESH[T.True]         -1.0069      0.077    -13.027      0.000      -1.158      -0.855
# UGDS_25abv_AVG_THRESH[T.True]     0.3578      0.067      5.378      0.000       0.227       0.488
# =================================================================================================
# """

# %%
smf.ols('md_earn_wne_p10 ~ CONTROL_PUBLIC*UGDS_10000_THRESH', data=train_data).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        md_earn_wne_p10   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     25.22
# Date:                Wed, 13 Mar 2019   Prob (F-statistic):           3.53e-16
# Time:                        20:40:55   Log-Likelihood:                -49427.
# No. Observations:                4515   AIC:                         9.886e+04
# Df Residuals:                    4511   BIC:                         9.889e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                         3.275e+04    250.971    130.475      0.000    3.23e+04    3.32e+04
# CONTROL_PUBLIC[T.True]                            -151.9547    472.702     -0.321      0.748   -1078.682     774.772
# UGDS_10000_THRESH[T.True]                         1.159e+04   2522.644      4.594      0.000    6642.296    1.65e+04
# CONTROL_PUBLIC[T.True]:UGDS_10000_THRESH[T.True] -5400.0061   2672.436     -2.021      0.043   -1.06e+04    -160.721
# ==============================================================================
# Omnibus:                     3544.106   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           193177.645
# Skew:                           3.287   Prob(JB):                         0.00
# Kurtosis:                      34.363   Cond. No.                         19.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
